# %% [markdown]
# <a href="https://colab.research.google.com/github/ddoneu/ECON3916-Statistical-Machine-Learning/blob/main/InClass%20notes%20/%20Class%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rgdp=[1,2,3,4,5,6]

# %%
rgdp
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nations = ["A","B","C","D","E","F"]

# %%
nations
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
dict = {
    "nations":nations,
    "rgdp":rgdp,
    "inflation": [3,2,1,1,2,3],
    "unemp": [6,7,3,2,8,9],
    "index":["C1","C2","C3","C4","C5","C6"]
}

# %%
dict
# Out:
# {'nations': ['A', 'B', 'C', 'D', 'E', 'F'],
#  'rgdp': [1, 2, 3, 4, 5, 6],
#  'inflation': [3, 2, 1, 1, 2, 3],
#  'unemp': [6, 7, 3, 2, 8, 9],
#  'index': ['C1', 'C2', 'C3', 'C4', 'C5', 'C6']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#   nations  rgdp  inflation  unemp index
# 0       A     1          3      6    C1
# 1       B     2          2      7    C2
# 2       C     3          1      3    C3
# 3       D     4          1      2    C4
# 4       E     5          2      8    C5
# 5       F     6          3      9    C6

# %%
df["inflation"]
# Out:
# 0    3
# 1    2
# 2    1
# 3    1
# 4    2
# 5    3
# Name: inflation, dtype: int64

# %%
df ["misery_index"] = df["inflation"]+ df["unemp"]

# %%
df ["misery_index"]
# Out:
# 0     9
# 1     9
# 2     4
# 3     3
# 4    10
# 5    12
# Name: misery_index, dtype: int64

# %%
df
# Out:
#   nations  rgdp  inflation  unemp index  misery_index
# 0       A     1          3      6    C1             9
# 1       B     2          2      7    C2             9
# 2       C     3          1      3    C3             4
# 3       D     4          1      2    C4             3
# 4       E     5          2      8    C5            10
# 5       F     6          3      9    C6            12

# %%
rgdp
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for i in rgdp:
  if i > 3:
    print(i)
# Out:
# 4
# 5
# 6

# %%
len(df)
# Out:
# 6

# %%
range(len(df))
# Out:
# range(0, 6)

# %%
for i in range (len(df)):
  if df.loc[i,"rgdp"] > 3:
    print (df.loc [i,"nations"])
# Out:
# D
# E
# F

# %%
print(df)
# Out:
#   nations  rgdp  inflation  unemp index  misery_index
# 0       A     1          3      6    C1             9
# 1       B     2          2      7    C2             9
# 2       C     3          1      3    C3             4
# 3       D     4          1      2    C4             3
# 4       E     5          2      8    C5            10
# 5       F     6          3      9    C6            12

# %%
def my_function():
  print("Hello Husky!")

# %%
my_function()
# Out:
# Hello Husky!

# %%
def misery_index_fun(unemp,inf):
  z = unemp + inf
  return z

# %%
misery_index_fun(df["inflation"],df['unemp'])
# Out:
# 0     9
# 1     9
# 2     4
# 3     3
# 4    10
# 5    12
# dtype: int64

# %%
def gdp_filter(x):
  """This will filter out the nations name for certain benchmark x"""
  for i in range(len(df)):
    if df.loc[i,"rgdp"] > x:
      print(df.loc[i,"nations"])

# %%
gdp_filter(1)
# Out:
# B
# C
# D
# E
# F

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['rgdp'])
plt.title("RGDP")
plt.xlabel("Nations")
plt.ylabel("Real GDP")
# Out:
# Text(0, 0.5, 'Real GDP')
